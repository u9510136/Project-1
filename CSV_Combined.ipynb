# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Import CSV files

Seattle = pd.read_csv('Resources/sea_listings.csv')
Seattle.dropna() .T
Boston = pd.read_csv('Resources/bos_listings.csv')
Boston.dropna() .T
Chicago = pd.read_csv('Resources/chi_listings.csv')
Chicago.dropna() .T
San_Diego = pd.read_csv('Resources/sd_listings.csv')
San_Diego.dropna() .T
Austin = pd.read_csv('Resources/aus_listings.csv')
Austin.dropna() .T
Combined_Data = pd.read_csv('Resources/combined_data.csv')
# Out:
# C:\Users\chino\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\chino\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\chino\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2,15,18,27,32,33,40,43,52,53,64,66,67,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Merge CSV files
Combined = pd.concat([Seattle, Boston, Chicago, San_Diego, Austin], axis=0)

# Index by location
Combined.set_index('market', inplace=True)
Combined.sort_index(inplace=True, ascending=False)

# Print to CSV
Combined.to_dense().to_csv('Resources/combined_data.csv', index = False, sep=',', encoding='utf-8')

# View Combined DataFrame
Combined.head()
# Out:
#                        id                            listing_url  \
# market
# Temecula Valley  11909382  https://www.airbnb.com/rooms/11909382
# Temecula Valley  11721547  https://www.airbnb.com/rooms/11721547
# Seattle              2318      https://www.airbnb.com/rooms/2318
# Seattle          21841224  https://www.airbnb.com/rooms/21841224
# Seattle          21820453  https://www.airbnb.com/rooms/21820453
#
#                     scrape_id last_scraped  \
# market
# Temecula Valley  2.018110e+13   11/15/2018
# Temecula Valley  2.018110e+13   11/15/2018
# Seattle          2.018112e+13   2018-11-15
# Seattle          2.018112e+13   2018-11-15
# Seattle          2.018112e+13   2018-11-15
#
#                                                               name  \
# market
# Temecula Valley                  Elegance, privacy, and  oceanview
# Temecula Valley   Stunning beachside townhome, 1 min to the beach.
# Seattle          Casa Madrona - Urban Oasis, 1 block from the P...
# ...

# %%
Combined.loc[:,'latitude': 'longitude'].head ()
# Out:
#                   latitude   longitude
# market
# Temecula Valley  32.832150 -117.264998
# Temecula Valley  32.829073 -117.278277
# Seattle          47.610819 -122.290816
# Seattle          47.671302 -122.372274
# Seattle          47.640590 -122.343581
